# %% [markdown]
# # Sv Histograms for Intensity-Based Section

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

years = [2007,2008,2009,2010,2011,2013,2014,2015,2016] #,2017,2018
year_codes = [2007205,2008205,2009107,2010205,2011206,2013842,2014807,2015837,2016837] #,2017843,2018823
patch_size = 8

for y in tqdm(range(len(years)), desc="Loading Data"):
    var_name = f'patch_data_array_all_{years[y]}'
    globals()[var_name] = np.load(f'/scratch/disk5/ahmet/data/{years[y]}/{year_codes[y]}/'
                                  f'ACOUSTIC/GRIDDED/{year_codes[y]}_patch_data_array_all_{patch_size}w.npy',
                                  allow_pickle=True)
    indices_to_remove = np.where(globals()[var_name]['label'] == 'ignore')[0]
    globals()[var_name] = np.delete(globals()[var_name], indices_to_remove, axis=0)
    globals()[var_name]['total_elements'] = years[y] # Total elements colonuna yil yazdim
# Out:
# Loading Data: 100%|██████████| 9/9 [04:13<00:00, 28.14s/it]

# %%
data_arrays = []

for y in range(len(years)):
    var_name = f'patch_data_array_all_{years[y]}'
    data_arrays.append(globals()[var_name])

concatenated_data = np.concatenate(data_arrays, axis=0)

# %%
len(concatenated_data)
# Out:
# 90250960

# %%
# FINAL FIGURE

# %%
# Visualization: Equal bins (200)
plt.rcParams["axes.grid"] = False
plt.figure(figsize=(10,8))
plt.hist(concatenated_data['Sv_all_mean'], bins=101, color='blue', alpha=1, density=False)


plt.hist(concatenated_data['Sv_all_mean'], bins=[-75, -70, -65, -60, -55, 0], color='orange', alpha=0.50, edgecolor='black', density=False)
plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
plt.xlim(-76, 1)
plt.savefig('Sv_mean_all_data_custom_bins_combined', dpi=600)
plt.show()

# %%
data = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based2/data_8w_IntensityBased2FIXED_16Batch_200Ep_100Iter_320000_FIXED.npy')
patch_class = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based2/patch_class_8w_IntensityBased2_16Batch_200Ep_100Iter_320000.npy')
years = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based2/years_8w_IntensityBased2_16Batch_200Ep_100Iter_320000.npy')
center_coordinates = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based2/center_coordinates_8w_IntensityBased2_16Batch_200Ep_100Iter_320000.npy')

# %%
average_values = np.mean(data, axis=(1, 2, 3))
plt.rcParams["axes.grid"] = False

plt.figure(figsize=(10,8))

plt.hist(average_values, bins=101, color='blue', alpha=1)
plt.hist(average_values, bins=[-75, -70, -65, -60, -55, 0], color='orange', alpha=0.55, edgecolor='black')

plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
plt.xlim(-76, 1)
plt.savefig('Sv_mean_smpled_data_custom_bins_combined', dpi=600)
plt.show()

# %%
#year_based = concatenated_data[concatenated_data['total_elements']==2007]

# %%
plt.figure(figsize=(10,8))
plt.hist(concatenated_data['Sv_all_mean'], bins=100, color='blue', alpha=0.7, cumulative=True)
plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
plt.xlim(-76, 1)
#plt.ylim(0, 1000000)
#plt.savefig('Sv_mean_all_data_equal_bins', dpi=600)
plt.show()

# %%
# Clean the data by removing NaN values
clean_data = concatenated_data['Sv_all_mean'][~np.isnan(concatenated_data['Sv_all_mean'])]

bin_edges = np.quantile(clean_data, np.linspace(0.20, 0.99, 5))
bin_edges
# Out:
# array([-74.72161583, -73.73992911, -72.16794618, -69.20090471,
#        -18.70712364])

# %%
# Clean the data by removing NaN values
clean_data = concatenated_data['Sv_all_mean'][~np.isnan(concatenated_data['Sv_all_mean'])]

bin_edges = np.quantile(clean_data, np.linspace(0.12, 0.99, 5))
bin_edges
# Out:
# array([-74.94433597, -74.10012005, -72.5542288 , -69.60135641,
#        -18.70712364])

# %%
bin_edges = np.quantile(clean_data[clean_data<-39.5], np.linspace(0.1, 0.99, 5))
bin_edges
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 # ADJUSTING -55
#       2
#       3 # Now calculate the quantile-based bin edges
# ----> 4 bin_edges = np.quantile(clean_data[clean_data<-39.5], np.linspace(0.12, 0.99, 5))
#       5 bin_edges
#
# NameError: name 'clean_data' is not defined

# %%
plt.figure(figsize=(10, 8))

plt.hist(concatenated_data['Sv_all_mean'], bins=bin_edges, color='blue', alpha=0.7)

plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
plt.xlim(-76, 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 plt.figure(figsize=(10, 8))
# ----> 3 plt.hist(concatenated_data['Sv_all_mean'], bins=bin_edges, color='blue', alpha=0.7)
#       5 plt.xlabel('Mean $S_v$')
#       6 plt.ylabel('Frequency')
#
# NameError: name 'bin_edges' is not defined

# %%
import statsmodels.api as sm

fig = sm.qqplot(concatenated_data['Sv_all_mean'], line='60')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 5
#       2 import matplotlib.pyplot as plt
#       4 #create Q-Q plot with 45-degree line added to plot
# ----> 5 fig = sm.qqplot(concatenated_data['Sv_all_mean'], line='60')
#       6 plt.show()
#
# File ~/.virtualenvs/dino_plain/lib/python3.10/site-packages/statsmodels/graphics/gofplots.py:691, in qqplot(data, dist, distargs, a, loc, scale, fit, line, ax, **plotkwargs)
#     593 """
#     594 Q-Q plot of the quantiles of x versus the quantiles/ppf of a distribution.
#     595
#    (...)
#     686 .. plot:: plots/graphics_gofplots_qqplot.py
#     687 """
#     688 probplot = ProbPlot(
#     689     data, dist=dist, distargs=distargs, fit=fit, a=a, loc=loc, scale=scale
#     690 )
# --> 691 fig = probplot.qqplot(ax=ax, line=line, **plotkwargs)
#     692 return fig
#
# File ~/.virtualenvs/dino_plain/lib/python3.10/site-packages/statsmodels/graphics/gofplots.py:477, in ProbPlot.qqplot(self, xlabel, ylabel, line, other, ax, swap, **plotkwargs)
#     474         xlabel, ylabel = ylabel, xlabel
#     476 else:
# --> 477     fig, ax = _do_plot(
#     478         self.theoretical_quantiles,
#     479         self.sample_quantiles,
#     480         self.dist,
#     481         ax=ax,
#     482         line=line,
#     483         **plotkwargs,
#     484     )
#     485     if xlabel is None:
#     486         xlabel = "Theoretical Quantiles"
#
# File ~/.virtualenvs/dino_plain/lib/python3.10/site-packages/statsmodels/graphics/gofplots.py:1049, in _do_plot(x, y, dist, line, ax, fmt, step, **kwargs)
#    1047     if line not in ["r", "q", "45", "s"]:
#    1048         msg = "%s option for line not understood" % line
# -> 1049         raise ValueError(msg)
#    1051     qqline(ax, line, x=x, y=y, dist=dist)
#    1053 return fig, ax
#
# ValueError: 60 option for line not understood

# %%
borders_95_without_tail = np.linspace(-74.9765, np.quantile(clean_data, 0.99),6)
borders_95_without_tail
# Out:
# array([-74.9765    , -63.72262473, -52.46874946, -41.21487418,
#        -29.96099891, -18.70712364])

# %%
bin_edges = borders_95_without_tail

samples_per_bin = 320000 // 5

sampled_indices = []

for i in range(len(bin_edges) - 1):
    bin_indices = np.where((concatenated_data['Sv_all_mean'] >= bin_edges[i]) &
                           (concatenated_data['Sv_all_mean'] < bin_edges[i + 1]))[0]

    if len(bin_indices) >= samples_per_bin:
        sampled_bin_indices = np.random.choice(bin_indices, size=samples_per_bin, replace=False)
    else:
        print(f"Not enough samples in bin {i}, needed {samples_per_bin}, but only have {len(bin_indices)}.")
        sampled_bin_indices = bin_indices 

    sampled_indices.extend(sampled_bin_indices)

sampled_data = concatenated_data[sampled_indices]

print(f"Sampled data contains {len(sampled_data)} instances.")
# Out:
# Sampled data contains 320000 instances.

# %%
np.save('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based3/detailed_8w_IntensityBased3_16Batch_200Ep_100Iter_320000.npy', sampled_data)

# %%
plt.hist(sampled_data['Sv_all_mean'], bins=100, color='black', cumulative=False)
plt.title('Intensity-Based Sampled')
plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
#plt.xlim(-76, 1)


plt.show()

# %%
np.quantile(sampled_data['Sv_all_mean'], np.linspace(0.1, 0.99, 5))
# Out:
# array([-72.91486872, -60.49512514, -44.58932926, -31.88958102,
#        -18.75146423])

# %%
sampled_data
# Out:
# array([(1707764, 124, 'background', 0, 0, 0, -74.97405912, 2009),
#        (1352668, 132, 'background', 0, 0, 0, -65.60843149, 2008),
#        ( 591988, 220, 'background', 0, 0, 0, -74.52471089, 2010), ...,
#        ( 287060,   4, 'background', 0, 0, 0, -18.75414662, 2016),
#        (1035924,   4, 'background', 0, 0, 0, -25.65972051, 2007),
#        ( 767844,   4, 'background', 0, 0, 0, -19.23347855, 2014)],
#       dtype=[('center_x', '<i8'), ('center_y', '<i8'), ('label', '<U20'), ('count_1', '<i8'), ('count_2', '<i8'), ('count_3', '<i8'), ('Sv_all_mean', '<f8'), ('total_elements', '<i8')])

# %%
sampled_data[sampled_data['total_elements']==2016]
# Out:
# array([(2862476, 516, 'background', 0, 0,  0, -74.35553856, 2016),
#        (2355108, 236, 'background', 0, 0,  0, -72.14441723, 2016),
#        ( 180436,  20, 'background', 0, 0,  0, -72.72748246, 2016), ...,
#        ( 287932, 308, 'seabed', 0, 0, 15, -62.46555338, 2016),
#        (2202340, 308, 'seabed', 0, 0, 20, -60.742428  , 2016),
#        (1934020,  60, 'background', 0, 0,  0, -60.82810864, 2016)],
#       dtype=[('center_x', '<i8'), ('center_y', '<i8'), ('label', '<U20'), ('count_1', '<i8'), ('count_2', '<i8'), ('count_3', '<i8'), ('Sv_all_mean', '<f8'), ('total_elements', '<i8')])

# %%
np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based3/data_8w_IntensityBased3_16Batch_200Ep_100Iter_320000.npy').shape
# Out:
# (27, 4, 8, 8)

# %%
np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/YENI_Intensity_Based/data_8w_IntensityBased_16Batch_200Ep_100Iter_320000.npy').shape
# Out:
# (320000, 4, 8, 8)

# %%
# Visualization: Custom Bins
plt.figure(figsize=(10,8))
# Plot histogram of the average values with border lines for each bin
plt.hist(concatenated_data['Sv_all_mean'], bins=[-75, -70, -65, -60, -55, 0], color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
plt.xlim(-76, 1)
plt.savefig('Sv_mean_all_data_custom_bins', dpi=600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 plt.figure(figsize=(10,8))
#       3 # Plot histogram of the average values with border lines for each bin
# ----> 4 plt.hist(concatenated_data['Sv_all_mean'], bins=[-75, -70, -65, -60, -55, 0], color='blue', alpha=0.7, edgecolor='black')
#       5 plt.xlabel('Mean $S_v$')
#       6 plt.ylabel('Frequency')
#
# NameError: name 'concatenated_data' is not defined

# %%
data = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/YENI_Intensity_Based/data_8w_IntensityBased_16Batch_200Ep_100Iter_320000.npy')
patch_class = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based2/patch_class_8w_IntensityBased2_16Batch_200Ep_100Iter_320000.npy')
years = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based2/years_8w_IntensityBased2_16Batch_200Ep_100Iter_320000.npy')
center_coordinates = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Intensity_Based2/center_coordinates_8w_IntensityBased2_16Batch_200Ep_100Iter_320000.npy')

# %%
sampled_data[:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sampled_data[:4]
#
# NameError: name 'sampled_data' is not defined

# %%
average_values = np.mean(data, axis=(1, 2, 3))
plt.rcParams["axes.grid"] = False

plt.figure(figsize=(10,8))
# Plot histogram of the average values
plt.hist(average_values, bins=200, color='blue', alpha=0.7)
plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
plt.xlim(-76, 1)
plt.savefig('Sv_mean_sampled_data_equal_bins', dpi=600)
plt.show()

# %%
# Custom bins
plt.figure(figsize=(10,8))
plt.hist(average_values, bins=[-75, -70, -65, -60, -55, 0], color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Mean $S_v$')
plt.ylabel('Frequency')
plt.xlim(-76, 1)
plt.savefig('Sv_mean_smpled_data_custom_bins', dpi=600)
plt.show()

# %%
data_random = np.load('/scratch/disk5/ahmet/data/8w_Sampled_Data_9Years/Random/data_8w_RANDOM_16Batch_200Ep_100Iter_320000.npy')

# %%
np.quantile(data_random.mean(axis=(1,2,3)),np.linspace(0.1, 0.99, 5))
# Out:
# array([-74.98015198, -74.27865913, -72.86583845, -70.14376957,
#        -41.65713799])

# %%
data_random['Sv_all_mean']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data_random['Sv_all_mean']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data_random
# Out:
# array([[[[-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]],
#
#         [[-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]],
#
#         [[-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]],
#
#         [[-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]]],
#
#
#        [[[ -4.35161815,  -4.35161569,  -4.33985642, ...,  -4.35161745,
#            -4.35161815,  -4.35161569],
#          [-19.17922657, -19.17905649, -19.16725497, ..., -19.17918438,
#           -19.17922657, -19.17905649],
#          [-45.53734821, -45.50293513, -45.50008326, ..., -45.54446008,
#           -45.49625325, -45.50710512],
#          ...,
#          [-57.2289494 , -57.24224278, -57.5502542 , ..., -57.31279252,
#           -56.15577346, -56.71887665],
#          [-59.77891261, -59.81634723, -60.20287188, ..., -60.0050595 ,
#           -58.42130197, -59.18728175],
#          [-64.11788621, -64.27454357, -64.88276961, ..., -65.06924444,
#           -62.05868163, -63.50932641]],
#
#         [[-55.23924476, -54.7455364 , -51.83531126, ..., -52.9247183 ,
#           -55.17144983, -55.0773785 ],
#          [-61.16722949, -60.29838857, -55.49441187, ..., -54.62883885,
#           -60.28527122, -61.98370484],
#          [-69.08151129, -70.30879965, -63.9476533 , ..., -63.88584443,
#           -70.23832095, -65.95396158],
#          ...,
#          [-64.18227861, -70.94639733, -69.43981771, ..., -67.26697675,
#           -58.92793018, -66.15682956],
#          [-63.22300525, -71.26778538, -66.78458192, ..., -73.01275431,
#           -52.55853122, -74.53707725],
#          [-72.40404254, -68.36523639, -59.3327807 , ..., -74.7231975 ,
#           -59.44995698, -70.59514914]],
#
#         [[-75.        , -72.86533088, -62.26127878, ..., -67.48835719,
#           -61.31045576, -64.20324388],
#          [-75.        , -61.24954283, -75.        , ..., -75.        ,
#           -74.58060433, -75.        ],
#          [-69.30158599, -66.70530928, -63.71056631, ..., -70.77396224,
#           -69.56038245, -75.        ],
#          ...,
#          [-68.89007743, -73.50289621, -71.44434975, ..., -73.06031571,
#           -60.03352804, -68.59737669],
#          [-67.08601222, -71.18747439, -75.        , ..., -74.50320413,
#           -62.85240681, -66.66832461],
#          [-62.44868325, -66.58009745, -66.26706376, ..., -68.32195355,
#           -68.19916073, -68.38635191]],
#
#         [[-75.        , -66.65696878, -75.        , ..., -58.95114462,
#           -73.83682456, -61.27303287],
#          [-65.12939664, -67.79574582, -64.48420833, ..., -74.88452331,
#           -75.        , -75.        ],
#          [-63.51639521, -59.90026526, -75.        , ..., -65.01137079,
#           -75.        , -64.05214768],
#          ...,
#          [-66.4063173 , -60.82294972, -75.        , ..., -73.34102839,
#           -71.33581423, -61.84691227],
#          [-69.37248131, -68.34457206, -65.90874568, ..., -65.59769855,
#           -65.51957749, -63.01792934],
#          [-75.        , -68.40680249, -69.30345582, ..., -66.63975791,
#           -62.03416488, -65.48212904]]],
#
#
#        [[[-69.91084281, -68.53619717, -68.1601651 , ..., -67.72535473,
#           -70.75656844, -69.60539926],
#          [-68.5743137 , -69.15005698, -66.79975531, ..., -68.97381531,
#           -69.49077666, -68.48031041],
#          [-69.25738584, -70.99590781, -67.5300152 , ..., -69.78606364,
#           -70.10324718, -68.411385  ],
#          ...,
#          [-69.68857265, -66.75081073, -68.57238605, ..., -69.62982739,
#           -70.56958255, -70.32292313],
#          [-68.14790133, -62.43511   , -68.89993601, ..., -69.25242653,
#           -70.0395488 , -69.51089953],
#          [-68.98868989, -61.33644333, -70.59812227, ..., -70.30448033,
#           -70.95047588, -70.90349137]],
#
#         [[-66.05135551, -48.79088441, -52.51843585, ..., -66.79184812,
#           -66.08661917, -65.52240017],
#          [-68.69588274, -49.41432579, -62.25444636, ..., -68.50787061,
#           -69.45959168, -68.15534277],
#          [-70.72720207, -64.94556758, -75.        , ..., -69.74049206,
#           -70.30436216, -70.6802221 ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -72.12488095, -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -73.50568545],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -72.73504342, -65.45110646]],
#
#         [[-75.        , -69.06848829, -69.82039613, ..., -59.6644039 ,
#           -73.84735317, -75.        ],
#          [-75.        , -75.        , -68.72940103, ..., -67.71880582,
#           -74.28298868, -75.        ],
#          [-75.        , -74.5648029 , -65.90917684, ..., -72.04210606,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -60.94091573, -75.        , ..., -75.        ,
#           -66.90113418, -75.        ],
#          [-68.86101602, -60.62080774, -75.        , ..., -75.        ,
#           -66.94549084, -75.        ],
#          [-67.13883881, -60.81423077, -75.        , ..., -75.        ,
#           -71.92023517, -75.        ]],
#
#         [[-75.        , -74.87494847, -69.59281478, ..., -64.86832642,
#           -75.        , -75.        ],
#          [-74.78882538, -71.17446651, -69.85894654, ..., -67.96723627,
#           -75.        , -75.        ],
#          [-74.64279837, -74.43173764, -73.52856439, ..., -74.91244738,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -70.94517919],
#          [-73.08524687, -75.        , -75.        , ..., -75.        ,
#           -73.894795  , -68.88101812],
#          [-72.74447544, -72.88531142, -75.        , ..., -75.        ,
#           -73.96474991, -70.1376718 ]]],
#
#
#        ...,
#
#
#        [[[-71.94116441, -73.29096443, -74.15907979, ..., -75.        ,
#           -73.74853555, -75.        ],
#          [-74.75678769, -73.17330194, -73.74821735, ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -74.82719096, ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -73.26968902, -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -72.74314594, -73.91650244, ..., -72.84877172,
#           -74.51462684, -73.96342113],
#          [-74.62206854, -74.09436087, -71.26579177, ..., -71.12486414,
#           -70.3027082 , -70.70207004]],
#
#         [[-72.55887888, -73.41557441, -74.08424851, ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -73.91699518, ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -73.05099559],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -74.69241577, -72.28727814]],
#
#         [[-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -74.34796354,
#           -72.4472091 , -73.55033742],
#          [-75.        , -75.        , -73.66770028, ..., -73.22184232,
#           -74.98113082, -73.29224977],
#          [-75.        , -75.        , -73.949635  , ..., -73.09316326,
#           -75.        , -73.26918032]],
#
#         [[-75.        , -72.46751879, -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -74.93514976, -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-73.24364236, -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]]],
#
#
#        [[[-72.58825684, -71.96608076, -70.96797329, ..., -70.82704115,
#           -67.36102972, -71.49642171],
#          [-75.        , -75.        , -74.4592125 , ..., -74.04874888,
#           -69.95160866, -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -70.24239286, -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]],
#
#         [[-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]],
#
#         [[-73.49835573, -75.        , -74.92914632, ..., -75.        ,
#           -71.62033506, -75.        ],
#          [-73.23386464, -75.        , -74.65316515, ..., -75.        ,
#           -73.66799037, -75.        ],
#          [-69.79047216, -75.        , -75.        , ..., -75.        ,
#           -70.87112675, -75.        ],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -71.98639936, -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -70.77660353, -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -72.64178064, -70.88059767]],
#
#         [[-72.1262125 , -75.        , -69.8478664 , ..., -75.        ,
#           -74.32047285, -72.59576165],
#          [-75.        , -75.        , -71.05785748, ..., -75.        ,
#           -72.6780896 , -67.87405536],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -71.94202575, -67.11364921],
#          ...,
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -74.13228367, -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ],
#          [-75.        , -75.        , -75.        , ..., -75.        ,
#           -75.        , -75.        ]]],
#
#
#        [[[-56.98301962, -58.32346422, -52.53826577, ..., -48.65784538,
#           -50.97434335, -50.17473855],
#          [-54.55197897, -58.43226274, -57.08006411, ..., -49.10765926,
#           -54.03459804, -53.96404302],
#          [-58.83552148, -55.3197758 , -59.89374158, ..., -50.65155339,
#           -64.70230812, -58.894317  ],
#          ...,
#          [-63.83402216, -62.67013031, -67.47792834, ..., -54.1925935 ,
#           -56.85002925, -60.24812557],
#          [-66.19049908, -65.99067503, -68.28247474, ..., -59.38347311,
#           -65.41470251, -61.9466312 ],
#          [-68.38238168, -62.81078465, -63.9864299 , ..., -66.39621412,
#           -72.56373396, -75.        ]],
#
#         [[-64.29659976, -67.04716894, -68.41040134, ..., -71.60556461,
#           -66.51826951, -61.85123312],
#          [-66.64780887, -70.38442591, -68.43415603, ..., -71.72323329,
#           -75.        , -60.98144055],
#          [-74.28226401, -75.        , -74.05942078, ..., -68.7404308 ,
#           -70.31470855, -61.9110369 ],
#          ...,
#          [-73.66582267, -71.85838527, -66.67731686, ..., -74.13502706,
#           -74.76824269, -75.        ],
#          [-69.67656118, -74.70060092, -71.28572812, ..., -75.        ,
#           -75.        , -72.49502449],
#          [-68.10526237, -74.82100706, -75.        , ..., -69.46826327,
#           -72.42776969, -73.30798736]],
#
#         [[-74.66531179, -71.17992664, -68.06671871, ..., -75.        ,
#           -61.17816252, -66.83271174],
#          [-75.        , -75.        , -74.50260798, ..., -67.84488473,
#           -60.95622582, -72.4728892 ],
#          [-75.        , -75.        , -75.        , ..., -67.45902359,
#           -64.2618442 , -73.12035686],
#          ...,
#          [-68.99550988, -72.67147298, -75.        , ..., -75.        ,
#           -71.50922376, -75.        ],
#          [-69.08165666, -73.37949384, -72.8749027 , ..., -75.        ,
#           -71.01990855, -75.        ],
#          [-69.6264829 , -72.29238955, -74.9671521 , ..., -74.89682285,
#           -72.52715611, -75.        ]],
#
#         [[-65.6561051 , -75.        , -70.22737329, ..., -65.76190058,
#           -66.67871387, -70.35658354],
#          [-69.37719362, -75.        , -71.78499352, ..., -68.6369697 ,
#           -66.18071482, -69.30669753],
#          [-75.        , -75.        , -75.        , ..., -67.36396378,
#           -64.2020185 , -73.56519814],
#          ...,
#          [-75.        , -75.        , -71.66694103, ..., -74.34255362,
#           -75.        , -75.        ],
#          [-75.        , -74.98551933, -72.19338151, ..., -74.15302149,
#           -75.        , -75.        ],
#          [-74.22197792, -74.42133465, -74.55032028, ..., -74.18679233,
#           -75.        , -75.        ]]]])
